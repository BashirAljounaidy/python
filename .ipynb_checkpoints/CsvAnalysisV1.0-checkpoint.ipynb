# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
# %matplotlib inline 
#set pd for 2 decimal float 
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# #Dont run This only if you want to update data

# %%
import requests
access_key= '18cd493de774f04dcc4c05e6c7142216'
symbol= input('Please Enter Company Symbol ')
api_result = requests.get('http://api.marketstack.com/v1/eod?access_key='+access_key+'&symbols='+symbol+'&sort=ASC&limit=252')
api_response = api_result.json()
print('Done')
# Out:
# Please Enter Company Symbol AAPL
# Done

# %%
#Data Cleaning 
df=df.from_dict(api_response['data'])
df.drop(["adj_high","adj_close","adj_close","adj_open","adj_volume","symbol","exchange","adj_low"], axis=1,inplace=True)
df["date"].replace('T00:00:00+0000','', inplace=True)
df["date"]=df["date"].apply(lambda x: x.replace("T00:00:00+0000", ""))
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
df.columns = ['Date', 'Open','High','Low','Close','Volume']
df.to_csv('./Saved/'+symbol+'.csv',index=False)
df
# Out:
#            Date   Open   High    Low  Close       Volume
# 0    2020-03-23 228.08 228.50 212.61 224.37  84188208.00
# 1    2020-03-24 236.36 247.69 234.30 246.88  71882773.00
# 2    2020-03-25 250.75 258.25 244.30 245.52  75900510.00
# 3    2020-03-26 246.52 258.68 246.36 258.44  63140169.00
# 4    2020-03-27 252.75 255.87 247.05 247.74  51054153.00
# ..          ...    ...    ...    ...    ...          ...
# 247  2021-03-16 125.70 127.22 124.72 125.57 115227936.00
# 248  2021-03-17 124.05 125.86 122.34 124.76 111932636.00
# 249  2021-03-18 122.88 123.18 120.33 120.53 118907153.00
# 250  2021-03-19 119.90 121.43 119.67 119.99 185023200.00
# 251  2021-03-22 120.33 123.87 120.26 123.39 111912284.00
#
# [252 rows x 6 columns]

# %%
#read Data form CSV
#fileName="./Saved/AAPL.csv"#input("please put file name ")
fileName="./Saved/"+symbol+".csv"
df=pd.read_csv(fileName,header=0)
df
# Out:
#            Date   Open   High    Low  Close       Volume
# 0    2020-03-23 228.08 228.50 212.61 224.37  84188208.00
# 1    2020-03-24 236.36 247.69 234.30 246.88  71882773.00
# 2    2020-03-25 250.75 258.25 244.30 245.52  75900510.00
# 3    2020-03-26 246.52 258.68 246.36 258.44  63140169.00
# 4    2020-03-27 252.75 255.87 247.05 247.74  51054153.00
# ..          ...    ...    ...    ...    ...          ...
# 247  2021-03-16 125.70 127.22 124.72 125.57 115227936.00
# 248  2021-03-17 124.05 125.86 122.34 124.76 111932636.00
# 249  2021-03-18 122.88 123.18 120.33 120.53 118907153.00
# 250  2021-03-19 119.90 121.43 119.67 119.99 185023200.00
# 251  2021-03-22 120.33 123.87 120.26 123.39 111912284.00
#
# [252 rows x 6 columns]

# %%
#Add calulated Columns 
# add calculated col Candle stick 
df['Candle'] = df.Close - df.Open
df['Ch%']=(df.Candle/df.Open)*100
#Highs percent of open price 
df['H%']=((df.High-df.Open)/df.Open)*100

#lows percent of open price
df['L%']=((df.Open-df.Low)/df.Open)*100

#High - low value 
df['HL']=df.High-df.Low
df['HLCH%']=(df.HL/df.Open)*100

#Low to close 
df['LtC']=df.Close-df.Low
df['LtC%']=(df.LtC/df.Open)*100

# Converte date col to date type then get day name by date value 
df['Date'] = pd.to_datetime(df['Date'])
df['Day'] = df['Date'].dt.day_name()
#Calculate mean , median 

# apply up trend if Candle is postive other is negative 
df['UPTrend'] = np.where(df['Candle']>0, True, False)

#Filter unwanted column
FilteredDf= df#[['Date','Open','Candle','Ch%','H%','L%','HL','HLCH%','LtC%','Day','UPTrend']]
uptrend= FilteredDf.loc[df['UPTrend'] == True]
downtrend= FilteredDf.loc[df['UPTrend'] == False]


df['Date'].iloc[0]
print("Data from :")
print(df['Date'].iloc[0])
print("Data to :")
print(df['Date'].iloc[-1])
df.describe()
#Monday=df.loc[df['Day'] == 'Monday']
#trend count calculate the up trend squences and down trend squences
#Monday.describe()
# Out:
# Data from :
# 2020-03-23 00:00:00
# Data to :
# 2021-03-22 00:00:00
#         Open   High    Low  Close       Volume  Candle    Ch%     H%     L%  \
# count 252.00 252.00 252.00 252.00       252.00  252.00 252.00 252.00 252.00
# mean  222.85 225.90 219.90 223.15  87176254.72    0.29   0.04   1.37   1.44
# std   121.23 122.81 120.04 121.76  55727482.95    4.54   1.84   1.15   1.36
# min   104.54 110.19 103.10 106.84  20254653.00  -16.61  -5.71   0.01   0.01
# 25%   120.97 122.84 119.25 120.98  39682328.00   -1.89  -1.10   0.49   0.49
# 50%   135.80 136.85 133.65 135.06  81500378.00    0.23   0.11   1.06   1.03
# 75%   321.40 323.64 317.64 321.97 115575466.00    2.53   1.16   2.04   1.99
# max   514.79 515.14 500.33 506.09 332607163.00   20.43   5.30   5.40   7.70
#
#           HL  HLCH%    LtC   LtC%
# count 252.00 252.00 252.00 252.00
# mean    6.00   2.81   3.25   1.47
# std     4.12   1.39   3.47   1.29
# min     1.27   0.94   0.02   0.01
# 25%     3.09   1.73   0.79   0.48
# 50%     4.83   2.55   2.21   1.24
# 75%     7.81   3.47   4.47   2.09
# max    22.47  10.67  21.74   8.39

# %%
#functions 
def trendCount(df):
    trendCount=[]
    ncount=0
    pcount=0
    for index, row in df.iterrows():
        if row['Candle']<0:
            ncount=ncount-1
            trendCount.append(ncount)
            pcount=0
        if row['Candle']>=0:
            pcount=pcount+1
            trendCount.append(pcount)
            ncount=0
    return trendCount

def preClose(df):
    trendCount=[]
    for index, row in df.iterrows():
        trendCount.append(df['Close'].iloc[index-1])
    return trendCount

# %%
# Out:
# Put price  1919.4 At 2020-03-23 00:00:00

# %%
#Days
Monday=df.loc[df['Day'] == 'Monday']
Tuesday=df.loc[df['Day'] == 'Tuesday']
Wednesday=df.loc[df['Day'] == 'Wednesday']
Thursday=df.loc[df['Day'] == 'Thursday']
Friday=df.loc[df['Day'] == 'Friday']

#TimeFrame
#Spicific Date 
Mar15=df.loc[df['Date']>='2021-03-15']

#last 5 days 
LastW=df.set_index("Date").last("1W")

#Month
Last1M=df.set_index("Date").last("1M")

#6month
Last6M=df.set_index("Date").last("6M")

#Year Start
thisY=df.set_index("Date").last("1Y")
thisY.describe()
# Out:
#         Open   High    Low  Close       Volume  Candle   Ch%    H%    L%  \
# count  54.00  54.00  54.00  54.00        54.00   54.00 54.00 54.00 54.00
# mean  129.55 131.07 127.51 129.30 111815220.13   -0.26 -0.19  1.18  1.57
# std     6.57   6.48   6.46   6.62  30098123.58    2.02  1.58  0.99  1.18
# min   119.03 121.00 116.21 116.36  60145130.00   -4.57 -3.78  0.01  0.06
# 25%   123.83 125.75 121.41 124.18  90276380.00   -1.64 -1.32  0.44  0.79
# 50%   128.77 130.86 127.63 129.19 105699034.00   -0.38 -0.29  0.80  1.37
# 75%   135.67 136.24 133.61 134.78 127002086.00    0.84  0.63  1.71  2.06
# max   143.60 145.09 141.37 143.16 185023200.00    4.04  3.26  4.39  5.06
#
#          HL  HLCH%   LtC  LtC%
# count 54.00  54.00 54.00 54.00
# mean   3.55   2.75  1.78  1.38
# std    1.62   1.24  1.62  1.26
# min    1.56   1.14  0.06  0.05
# 25%    2.43   1.83  0.40  0.30
# 50%    3.25   2.54  1.58  1.20
# 75%    4.30   3.30  2.63  2.00
# max    8.55   6.72  7.47  6.04

# %%
#if previous cahnge is negative 
def trendCount(df):
    trendCount=[]
    ncount=0
    pcount=0
    for index, row in df.iterrows():
        if row['Candle']<0:
            ncount=ncount-1
            trendCount.append(ncount)
            pcount=0
        if row['Candle']>=0:
            pcount=pcount+1
            trendCount.append(pcount)
            ncount=0
    return trendCount

# %% [markdown]
# table = pd.pivot_table(Last6M, values=['Ch%','H%','L%','HLCH%','LtC%'], index=['Day','UPTrend'],
#                     aggfunc={'Ch%': [min,max,np.mean,np.median],
#                             'H%': [min,max,np.mean,np.median],
#                             'L%': [min,max,np.mean,np.median],
#                             'HLCH%':[min,max,np.mean,np.median],
#                             'LtC%':[min,max,np.mean,np.median]})
# table

# %% [markdown]
# Last6M.describe()
# #Last6M[['Open']].mode()
# Last6M

# %% [markdown]
# #Described=Last6M'''.loc[Last6M['UPTrend'] == True].loc[Last6M['Day'] == 'Friday' ]'''.describe()
# Described=Last6M.describe()
#
# Described

# %%
import pandas as pd
import numpy as np
#thisY=df.set_index("Date").last("6M")
var=thisY
Described=var.describe()
DescribedUp=var.loc[var['UPTrend'] == True].describe()
DescribedDown=var.loc[var['UPTrend'] == False].describe()
def PrintHL(Described):
    print('#High')
    print('Max {:.2f}'.format(Described['H%'].iloc[7]),' :',float(float(priceToday)*((Described['H%'].iloc[7]/100)+1)))
    print('Mid {:.2f}'.format(Described['H%'].iloc[5]),' :',float(float(priceToday)*((Described['H%'].iloc[5]/100)+1)))
    print('Mean {:.2f}'.format(Described['H%'].iloc[1]),' :',float(float(priceToday)*((Described['H%'].iloc[1]/100)+1)))
    print('Min {:.2f}'.format(Described['H%'].iloc[3]),' :' ,float(float(priceToday)*((Described['H%'].iloc[3]/100)+1)))

    print('#Low')
    print('Min {:.2f}'.format(Described['L%'].iloc[3]),' : ',float(float(priceToday)*(1-(Described['L%'].iloc[3]/100))))
    print('Mean {:.2f}'.format(Described['L%'].iloc[1]),' : ',float(float(priceToday)*(1-(Described['L%'].iloc[1]/100))))
    print('Mid {:.2f}'.format(Described['L%'].iloc[5]),' : ',float(float(priceToday)*(1-(Described['L%'].iloc[5]/100))))
    print('Max {:.2f}'.format(Described['L%'].iloc[7]),' : ', float(float(priceToday)*(1-(Described['L%'].iloc[7]/100))))
    
priceToday=float(input("Please Enter Price Today "))
print('Open Price= ',priceToday)
print('General')
PrintHL(Described)
print('#################################################')
print('UpTrend')
PrintHL(DescribedUp)
print('#################################################')
print('DownTrend')
PrintHL(DescribedDown)
# Out:
# Please Enter Price Today 123.33
# Open Price=  123.33
# General
# #High
# Max 4.39  : 128.7406659192825
# Mid 0.80  : 124.3144385362836
# Mean 1.18  : 124.78476192466991
# Min 0.01  : 123.3390844136712
# #Low
# Min 0.06  :  123.25825479930192
# Mean 1.57  :  121.39579963427572
# Mid 1.37  :  121.64366765797202
# Max 5.06  :  117.08591072498501
# #################################################
# UpTrend
# #High
# Max 4.39  : 128.7406659192825
# Mid 1.46  : 125.12939513905683
# Mean 1.77  : 125.5138389764019
# Min 0.50  : 123.94201056507124
# #Low
# Min 0.06  :  123.25825479930192
# Mean 1.04  :  122.04962113459159
# Mid 0.81  :  122.33450210032123
# Max 4.34  :  117.9786578862314
# #################################################
# DownTrend
# #High
# Max 2.61  : 126.54544446445351
# Mid 0.55  : 124.00431940590828
# Mean 0.74  : 124.2438337895139
# Min 0.01  : 123.3390844136712
# #Low
# Min 0.53  :  122.67129808808731
# Mean 1.96  :  120.91070626307364
# Mid 1.58  :  121.37685106069536
# Max 5.06  :  117.08591072498501

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
#var=df["H%"]

var=pd.DataFrame(trendCount(thisY))#.loc[df['Day'] == 'Monday']
plt.pyplot.hist(var)

# set x/y labels and plot title
plt.pyplot.xlabel("data")
plt.pyplot.ylabel("Counts")
plt.pyplot.title("Counts")
thisY.describe()

# %%
Last6M.describe()
# Out:
#          Open    High     Low   Close     Volume  Candle    Ch%     H%     L%  \
# count  117.00  117.00  117.00  117.00     117.00  117.00 117.00 117.00 117.00
# mean  3194.25 3228.23 3151.54 3187.91 4099237.45   -6.34  -0.19   1.07   1.33
# std     96.24   97.93   96.33   98.35 1343975.32   47.18   1.47   0.87   1.10
# min   3005.00 3009.00 2881.00 2951.95 1451917.00 -121.60  -3.85   0.00   0.01
# 25%   3127.03 3149.56 3087.12 3117.02 3070919.00  -34.44  -1.07   0.42   0.49
# 50%   3188.50 3210.13 3144.02 3185.07 3808676.00   -4.54  -0.15   0.77   1.03
# 75%   3250.00 3292.00 3211.30 3262.13 4708887.00   18.25   0.58   1.67   1.79
# max   3467.99 3496.24 3424.22 3443.63 8396081.00  100.52   3.10   4.37   6.04
#
#           HL  HLCH%    LtC   LtC%
# count 117.00 117.00 117.00 117.00
# mean   76.69   2.40  36.38   1.14
# std    34.05   1.05  28.65   0.90
# min    25.96   0.81   0.31   0.01
# 25%    53.48   1.68  14.47   0.44
# 50%    67.61   2.10  31.65   0.99
# 75%    91.77   2.91  53.45   1.65
# max   239.66   7.13 119.46   3.98

# %%
#thisY.plot.scatter(x='Date',y='H%')
var=Last6M.reset_index()
ax1 = var.plot.scatter(x='Ch%',y='Date')
#ax2 = var.plot.scatter(x='L%',y='Open')
Last6M.loc[Last6M['UPTrend'] == True].describe()
# Out:
#          Open    High     Low   Close     Volume  Candle   Ch%    H%    L%  \
# count   56.00   56.00   56.00   56.00      56.00   56.00 56.00 56.00 56.00
# mean  3177.41 3228.71 3156.59 3209.59 4003093.88   32.17  1.01  1.61  0.65
# std     84.58   92.93   85.03   89.10 1210226.67   27.91  0.87  0.89  0.48
# min   3017.99 3074.90 2980.98 3048.41 2335339.00    0.83  0.03  0.25  0.01
# 25%   3116.75 3144.43 3086.19 3134.56 3056923.00    9.70  0.31  0.79  0.30
# 50%   3171.01 3215.27 3147.75 3205.29 3768959.50   19.08  0.61  1.68  0.50
# 75%   3236.87 3302.26 3229.52 3284.55 4654803.00   48.10  1.55  2.06  0.99
# max   3349.94 3496.24 3339.55 3442.93 8364198.00  100.52  3.10  4.37  2.20
#
#           HL  HLCH%    LtC  LtC%
# count  56.00  56.00  56.00 56.00
# mean   72.12   2.27  52.99  1.67
# std    24.82   0.77  24.78  0.78
# min    39.07   1.24   7.16  0.23
# 25%    54.42   1.69  39.16  1.21
# 50%    64.90   2.05  49.35  1.54
# 75%    86.64   2.75  63.58  2.02
# max   156.69   4.68 111.27  3.48

# %% [markdown]
# %matplotlib inline
# import matplotlib as plt
# from matplotlib import pyplot
# var=df["L%"]
# plt.pyplot.hist(var)
# # set x/y labels and plot title
# plt.pyplot.xlabel("L%")
# plt.pyplot.ylabel("count")
# plt.pyplot.title("Lows")

# %% [markdown]
# #sns.boxplot(x="UPTrend", y="H%", data=df)
# pd.DataFrame(trendCount)
# sns.boxplot(x="UPTrend", y="L%", data=df)

# %%
df.corr()
# Out:
#            Open  High   Low  Close  Adj Close  Volume  Candle   Ch%    H%  \
# Open       1.00  1.00  1.00   0.99       0.99   -0.19   -0.18 -0.19 -0.21
# High       1.00  1.00  1.00   1.00       1.00   -0.16   -0.12 -0.13 -0.13
# Low        1.00  1.00  1.00   1.00       1.00   -0.23   -0.10 -0.12 -0.17
# Close      0.99  1.00  1.00   1.00       1.00   -0.20   -0.05 -0.07 -0.12
# Adj Close  0.99  1.00  1.00   1.00       1.00   -0.20   -0.05 -0.07 -0.12
# Volume    -0.19 -0.16 -0.23  -0.20      -0.20    1.00   -0.03 -0.01  0.40
# Candle    -0.18 -0.12 -0.10  -0.05      -0.05   -0.03    1.00  0.99  0.72
# Ch%       -0.19 -0.13 -0.12  -0.07      -0.07   -0.01    0.99  1.00  0.75
# H%        -0.21 -0.13 -0.17  -0.12      -0.12    0.40    0.72  0.75  1.00
# L%         0.11  0.07  0.01   0.01       0.01    0.42   -0.77 -0.76 -0.41
# HL         0.22  0.26  0.16   0.20       0.20    0.66   -0.16 -0.14  0.39
# HLCH%     -0.08 -0.05 -0.14  -0.10      -0.10    0.75   -0.09 -0.05  0.50
# LtC        0.01  0.07  0.02   0.10       0.10    0.39    0.67  0.68  0.66
# LtC%      -0.18 -0.12 -0.17  -0.09      -0.09    0.43    0.70  0.72  0.71
# UPTrend   -0.11 -0.07 -0.06  -0.01      -0.01   -0.04    0.77  0.77  0.58
#
#              L%    HL  HLCH%   LtC  LtC%  UPTrend
# Open       0.11  0.22  -0.08  0.01 -0.18    -0.11
# High       0.07  0.26  -0.05  0.07 -0.12    -0.07
# Low        0.01  0.16  -0.14  0.02 -0.17    -0.06
# Close      0.01  0.20  -0.10  0.10 -0.09    -0.01
# Adj Close  0.01  0.20  -0.10  0.10 -0.09    -0.01
# Volume     0.42  0.66   0.75  0.39  0.43    -0.04
# Candle    -0.77 -0.16  -0.09  0.67  0.70     0.77
# Ch%       -0.76 -0.14  -0.05  0.68  0.72     0.77
# H%        -0.41  0.39   0.50  0.66  0.71     0.58
# L%         1.00  0.62   0.58 -0.07 -0.10    -0.61
# HL         0.62  1.00   0.94  0.51  0.45    -0.11
# HLCH%      0.58  0.94   1.00  0.52  0.54    -0.07
# LtC       -0.07  0.51   0.52  1.00  0.97     0.51
# LtC%      -0.10  0.45   0.54  0.97  1.00     0.53
# UPTrend   -0.61 -0.11  -0.07  0.51  0.53     1.00

# %%
df[['Open','Ch%']].corr()
# Out:
#       Open   Ch%
# Open  1.00 -0.19
# Ch%  -0.19  1.00

# %%
sns.regplot(x="Open", y="Ch%", data=df.loc(df))
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Ch%'>

# %%
#Pivot Table only Important informtaion
table = pd.pivot_table(uptrend, values=['Ch%','H%','L%','HLCH%','LtC%'], index=['Day','UPTrend'],
                    aggfunc={'Ch%': [max,min,np.mean,np.median],
                            'H%': [max,min,np.mean,np.median],
                            'L%': [max,min,np.mean,np.median],
                            'HLCH%':[max,min,np.mean,np.median],
                            'LtC%':[max,min,np.mean,np.median]})
# Out:
# The Pearson Correlation Coefficient is 0.5776523700314733  with a P-value of P = 7.90068698393629e-24

# %%
groupeddf=df[['H%', 'Open']].groupby(['H%'])
groupeddf.head(2)
groupeddf
